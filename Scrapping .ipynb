# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show requests
# Out:
# Name: requests
# Version: 2.31.0
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache 2.0
# Location: C:\Users\HP\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, intake, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install beautifulsoup4

# %%
pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.2
# Summary: Screen-scraping library
# Home-page:
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License:
# Location: C:\Users\HP\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
li="https://www.jobberman.com/jobs"
re=requests.get(li)
re
# Out:
# <Response [200]>

# %%
data=BeautifulSoup(re.content,"lxml")
print(data.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js scroll-smooth" lang="en-ng">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <meta content="4hClu3W3PtjepabInbxYOahjMMOlzUNqWBY9OKZJtdA" name="google-site-verification"/>
#   <meta content="sQsEtfq2VF492imbmdM8HRIYyweCDj5m9tPn5HXH" name="csrf-token"/>
#   <link href="https://www.jobberman.com/listings/social-media-marketing-manager-8479gx" rel="prerender"/>
#   <link href="https://www.jobberman.com/listings/cartoon-animator-zp0jxd" rel="prerender"/>
#   <link href="https://www.jobberman.com/listings/cartoon-animator-5dkzg6" rel="prerender"/>
#   <link href="https://www.jobberman.com/listings/senior-accountant-074998" rel="prerender"/>
#   <link href="https://www.jobberman.com/listings/accountant-vwjkkg" rel="prerender"/>
#   <link href="https://www.jobberman.com/listings/area-sales-representative-d7g2dr" rel="prerender"/>
# ...

# %%
job_name=[]
for i in data.find_all("p", class_="text-lg font-medium break-words text-link-500"):
    job_name.append(i.text.strip())
print(job_name)
# Out:
# ['Social Media & Marketing Manager', 'Cartoon Animator', 'Cartoon Animator', 'Senior Accountant', 'Accountant', 'Area Sales Representative', 'Electrician', 'Sales & Marketing Lead', 'Vodcast Presenter', 'Street Interview Host', 'Field Sales & Onboarding Agent', 'WordPress Developer', 'Flutter Developer', 'Video Editor', 'Cinematographer', 'Sales Representative']

# %%
s=[]

for j in data.find_all("span", class_="mb-3 px-3 py-1 rounded bg-brand-secondary-100 mr-2 text-loading-hide"):
    s.append(j.text.strip())
    #salary=s[0:16] 
print(s)
len(s)
# Out:
# ['Lagos', 'Full Time', 'NGN\n                                                        \n                                150,000 - 250,000', 'Rest of Nigeria (Kwara)', 'Full Time', 'NGN\n                                                        \n                                75,000 - 150,000', 'Lagos', 'Full Time', 'NGN\n                                                        \n                                75,000 - 150,000', 'Lagos', 'Full Time', 'Confidential', 'Lagos', 'Full Time', 'NGN\n                                                        \n                                150,000 - 250,000', 'Rest of Nigeria (Nationwide)', 'Full Time', 'NGN\n                                                        \n                                150,000 - 250,000', 'Lagos', 'Full Time', 'NGN\n                                                        \n                                150,000 - 250,000', 'Remote (Work From Home)', 'Contract', 'NGN\n                                               
# ...

# %%
describe=[]
for h in data.find_all("p", class_="text-sm font-normal text-gray-700 md:text-gray-500 md:pl-5"):
    describe.append(h.text.strip())
print(describe)
len(describe)
# Out:
# ["We're hiring a creative Social Media & Marketing Manager to develop strategies that engage our target audience, build brand awareness, and drive user acquisition for our app. You'll collaborate with product and design teams to ensure messaging aligns with our mission of providing trusted care for families.", 'We are hiring cartoon animators in Kwara who can create fun and original animated content. If you’re creative and know how to turn simple ideas into engaging cartoons, this is for you.', 'We are looking for creative and skilled cartoon animators to join our content team. If you can create short animated movies and characters that bring stories to life, this is a great opportunity to grow your craft.', 'Cakes and Cream is looking to hire an experienced Senior Accountant to join our team.', 'Cakes and Cream is looking to hire an experienced Accountant to join our team. The ideal candidate will be able to gather an in-depth analysis of the basic functions of the business and mana
# ...

# %%
post=[]
for k in data.find_all("p", class_="ml-auto text-sm font-normal text-gray-700 text-loading-animate"):
    post.append(k.text.strip())
print(post)
len(post)
# Out:
# ['Yesterday', 'Yesterday', 'Yesterday', '2 days ago', '2 days ago', '2 days ago', '3 days ago', '3 days ago', '3 days ago', '3 days ago', '3 days ago', '3 days ago', '3 days ago', '3 days ago', '3 days ago', '4 days ago']
# 16

# %%
company=[]
for l in data.find_all("a", class_="text-loading-animate text-loading-animate-link"):
    company.append(l.text.strip())
print(company)
len(company)
# Out:
# ['ResourceBarge', 'BolRach Technologies Limited', 'BolRach Technologies Limited', 'Cakes and Cream', 'Cakes and Cream', 'Sancare Biomedical Limited', 'Mota-Engil NG', "O'Bounce Technologies", 'BolRach Technologies Limited', 'BolRach Technologies Limited', 'BolRach Technologies Limited', 'BolRach Technologies Limited', 'BolRach Technologies Limited', 'BolRach Technologies Limited', 'BolRach Technologies Limited', 'Un Phones Ltd']
# 16

# %%
l1,l2,l3,l4,l5,l6,l7,l8,l9=[],[],[],[],[],[],[],[],[]
for page in range(1,15):
    link=f"https://www.jobberman.com/jobs?page={page}"
    re=requests.get(link)
    data=BeautifulSoup(re.content,"lxml")
    role=data.find_all("p", class_="text-lg font-medium break-words text-link-500")
    job_function=data.find_all("p",class_="text-sm text-gray-500 text-loading-animate inline-block")
    company=data.find_all("a", class_="text-loading-animate text-loading-animate-link")
    work_type=data.find_all("span",class_="mb-3 px-3 py-1 rounded bg-brand-secondary-100 mr-2 text-loading-hide")
    details=data.find_all("p", class_="ml-auto text-sm font-normal text-gray-700 text-loading-animate")
    post=data.find_all("p", class_="text-sm font-normal text-gray-700 md:text-gray-500 md:pl-5")
    
    max_length=max(len(role),len(job_function),len(work_type),len(company),len(post),len(details))
    
    for i in range(max_length):
        if i >= len(role) or not role[i].text.strip():  
            continue 
        l1.append(role[i].text.strip()) 
        l2.append(job_function[i].text.strip() if i < len(job_function) else "N/A")
        l3.append(work_type[i].text.strip() if i < len(work_type) else "N/A")
        l4.append(company[i].text.strip() if i < len(company) else "N/A")
        l5.append(details[i].text.strip() if i < len(details) else "N/A")
        l6.append(post[i].text.strip() if i < len(post) else "N/A")
        for i in range(0, len(l3), 3):
            l7.append(l3[i])       # Every 1st item is City
            l8.append(l3[i + 1])   # Every 2nd item is Work Type
            l9.append(l3[i + 2].strip())
print("Scraping completed.")


#print("Scraping completed.")
# Cleaning up salary strings
#salaries = [salary.replace("NGN\n                                                        \n                                ", "").strip() for salary in salaries]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 26
#      24         for i in range(0, len(l3), 3):
#      25             l7.append(l3[i])       # Every 1st item is City
# ---> 26             l8.append(l3[i + 1])   # Every 2nd item is Work Type
#      27             l9.append(l3[i + 2].strip())
#      28 print("Scraping completed.")
#
# IndexError: list index out of range

# %%
import requests
from bs4 import BeautifulSoup

# Initialize lists
l1, l2, l3, l4, l5, l6, l7, l8, l9 = [], [], [], [], [], [], [], [], []

for page in range(1, 15):
    link = f"https://www.jobberman.com/jobs?page={page}"
    re = requests.get(link)
    data = BeautifulSoup(re.content, "lxml")

    role = data.find_all("p", class_="text-lg font-medium break-words text-link-500")
    job_function = data.find_all("p", class_="text-sm text-gray-500 text-loading-animate inline-block")
    company = data.find_all("a", class_="text-loading-animate text-loading-animate-link")
    work_type = data.find_all("span", class_="mb-3 px-3 py-1 rounded bg-brand-secondary-100 mr-2 text-loading-hide")
    details = data.find_all("p", class_="ml-auto text-sm font-normal text-gray-700 text-loading-animate")
    post = data.find_all("p", class_="text-sm font-normal text-gray-700 md:text-gray-500 md:pl-5")

    max_length = max(len(role), len(job_function), len(work_type), len(company), len(post), len(details))

    for i in range(max_length):
        if i >= len(role) or not role[i].text.strip():
            continue
        
        l1.append(role[i].text.strip())  
        l2.append(job_function[i].text.strip() if i < len(job_function) else "N/A")
        l3.append(work_type[i].text.strip() if i < len(work_type) else "N/A")
        l4.append(company[i].text.strip() if i < len(company) else "N/A")
        l5.append(details[i].text.strip() if i < len(details) else "N/A")
        l6.append(post[i].text.strip() if i < len(post) else "N/A")

# Fixing l3 extraction: Splitting City, Work Type, and Salary
for i in range(0, len(l3), 3):  # Every 3rd item represents one complete set
    l7.append(l3[i] if i < len(l3) else "N/A")        # City
    l8.append(l3[i + 1] if i + 1 < len(l3) else "N/A")  # Work Type
    l9.append(l3[i + 2] if i + 2 < len(l3) else "N/A")  # Salary

print("Scraping completed.")
# Out:
# Scraping completed.

# %%
city = work_type[0::3] # Every 3rd element starting from index 0 (City Names)
work_types =work_type[1::3] # Every 3rd element starting from index 1 (Work Type)
salaries = work_type[2::3]
print(city)
print(work_types)
print(salaries)
# Out:
# [<span class="mb-3 px-3 py-1 rounded bg-brand-secondary-100 mr-2 text-loading-hide">
#                                                             Lagos
#                                                     </span>, <span class="mb-3 px-3 py-1 rounded bg-brand-secondary-100 mr-2 text-loading-hide">
#                                                             Lagos
#                                                     </span>, <span class="mb-3 px-3 py-1 rounded bg-brand-secondary-100 mr-2 text-loading-hide">
#                                                             Lagos
#                                                     </span>, <span class="mb-3 px-3 py-1 rounded bg-brand-secondary-100 mr-2 text-loading-hide">
#                                                             Lagos
#                                                     </span>, <span class="mb-3 px-3 py-1 rounded bg-brand-secondary-100 mr-2 text-loading-hide">
# ...

# %%
file = pd.DataFrame({"Job_Role" :l1 ,'Job_function':l2,"Company_Name" : l4, "Description" : l5 , "Post_Time" : l6 })
file
# Out:
#                              Job_Role  \
# 0    Social Media & Marketing Manager
# 1                    Cartoon Animator
# 2                    Cartoon Animator
# 3                   Senior Accountant
# 4                          Accountant
# ..                                ...
# 219                        Hotel Cook
# 220                     Sales Manager
# 221  Regional Sales/Marketing Manager
# 222                   Operations Lead
# 223             Personal/Sales Driver
#
#                                           Job_function  \
# 0    Job Function\n                        : Market...
# 1    Job Function\n                        : Creati...
# 2    Job Function\n                        : Creati...
# 3    Job Function\n                        : Accoun...
# 4    Job Function\n                        : Accoun...
# ..                                                 ...
# 219  Job Function\n                        : Food S...
# ...

# %%
print(len(l1))
print(len(l2))
print(len(l3))
print(len(l4))
print(len(l5))
print(len(l6))
print(len(l7))
print(len(l8))
print(len(l9))
# Out:
# 224
# 224
# 224
# 224
# 224
# 224
# 75
# 75
# 75

# %%
l3 = l[1::3]  # Work type (every 2nd element in groups of 3)
l5 = l[0::3]

# %%
file.head(16)
# Out:
#                                          Job_Role  \
# 0                                      Agronomist
# 1                       Guest Service Agent (GSA)
# 2                    Business Development Officer
# 3   Executive Assistant to the Executive Director
# 4           Manager, Production Quality Assurance
# 5                    Business Development Manager
# 6                    Business Development Officer
# 7                    Business Development Officer
# 8                       Furniture Delivery Driver
# 9                                 Warehouse Staff
# 10                  Game Master (Snooker Rackers)
# 11                                       Marketer
# 12                        Student Liaison Officer
# 13                               Facility Manager
# 14                              Quantity Surveyor
# 15                           Social Media Manager
#
#                                          Job_function Work_type  \
# ...

# %%
file.tail(25)
# Out:
#                                       Job_Role  \
# 199                       Verification Officer
# 200                       Verification Officer
# 201                    Creative Content Writer
# 202                       Verification Officer
# 203                             Machine Helper
# 204                     Human Resource Manager
# 205                       Verification Officer
# 206                       Verification Officer
# 207                       Verification Officer
# 208                                 Accountant
# 209                       Verification Officer
# 210                    Quality Control Manager
# 211                     Social Media Assistant
# 212       Head of Finance & Investor Relations
# 213            Technical Product Manager (TPM)
# 214                      Social Media Marketer
# 215            Online Sales Agent/Telemarketer
# 216                          Quantity Surveyor
# 217              In-house Social Media Manager
# ...

# %%
file.iloc[200:224]
# Out:
#                                       Job_Role  \
# 200                       Verification Officer
# 201                    Creative Content Writer
# 202                       Verification Officer
# 203                             Machine Helper
# 204                     Human Resource Manager
# 205                       Verification Officer
# 206                       Verification Officer
# 207                       Verification Officer
# 208                                 Accountant
# 209                       Verification Officer
# 210                    Quality Control Manager
# 211                     Social Media Assistant
# 212       Head of Finance & Investor Relations
# 213            Technical Product Manager (TPM)
# 214                      Social Media Marketer
# 215            Online Sales Agent/Telemarketer
# 216                          Quantity Surveyor
# 217              In-house Social Media Manager
# 218  Team Lead, Business Development SME Loans
# ...

# %%
op=[]
for h in data.find_all("span",class_="mb-3 px-3 py-1 rounded bg-brand-secondary-100 mr-2 text-loading-hide"):
    op.append(h.text.split())
print(op)
w=op[1::3]
#print(w)
r=op[0::3]
#print(r)
# Out:
# [['Lagos'], ['Full', 'Time'], ['NGN', '250,000', '-', '400,000'], ['Imo'], ['Part', 'Time'], ['NGN', '75,000', '-', '150,000'], ['Lagos'], ['Full', 'Time'], ['NGN', '250,000', '-', '400,000'], ['Lagos'], ['Full', 'Time'], ['NGN', '150,000', '-', '250,000'], ['Abuja'], ['Full', 'Time'], ['NGN', '250,000', '-', '400,000'], ['Abuja'], ['Full', 'Time'], ['NGN', '250,000', '-', '400,000'], ['Remote', '(Work', 'From', 'Home)'], ['Contract'], ['NGN', '75,000', '-', '150,000'], ['Remote', '(Work', 'From', 'Home)'], ['Contract'], ['NGN', '75,000', '-', '150,000'], ['Abuja'], ['Full', 'Time'], ['NGN', '75,000', '-', '150,000'], ['Abeokuta', '&', 'Ogun', 'State'], ['Full', 'Time'], ['NGN', '75,000', '-', '150,000'], ['Lagos'], ['Full', 'Time'], ['NGN', '1,500,000', '-', '2,000,000'], ['Lagos'], ['Full', 'Time'], ['NGN', '1,500,000', '-', '2,000,000'], ['Lagos'], ['Internship', '&', 'Graduate'], ['NGN', '75,000', '-', '150,000'], ['Lagos'], ['Full', 'Time'], ['NGN', '150,000', '-', '250,000'], [
# ...

# %%
len(r)
# Out:
# 16

# %%
p=[]
for h1 in data.find_all("p",class_="text-sm text-gray-500 text-loading-animate inline-block"):
    p.append(h1.text.split())
print(p)
# Out:
# [['Job', 'Function', ':', 'Farming', '&', 'Agriculture'], ['Job', 'Function', ':', 'Admin', '&', 'Office'], ['Job', 'Function', ':', 'Management', '&', 'Business', 'Development'], ['Job', 'Function', ':', 'Admin', '&', 'Office'], ['Job', 'Function', ':', 'Quality', 'Control', '&', 'Assurance'], ['Job', 'Function', ':', 'Management', '&', 'Business', 'Development'], ['Job', 'Function', ':', 'Management', '&', 'Business', 'Development'], ['Job', 'Function', ':', 'Management', '&', 'Business', 'Development'], ['Job', 'Function', ':', 'Driver', '&', 'Transport', 'Services'], ['Job', 'Function', ':', 'Management', '&', 'Business', 'Development'], ['Job', 'Function', ':', 'Hospitality', '&', 'Leisure'], ['Job', 'Function', ':', 'Marketing', '&', 'Communications'], ['Job', 'Function', ':', 'Consulting', '&', 'Strategy'], ['Job', 'Function', ':', 'Estate', 'Agents', '&', 'Property', 'Management'], ['Job', 'Function', ':', 'Building', '&', 'Architecture'], ['Job', 'Function', ':', 'Marketing'
# ...

# %%
q=p[1::2]
q
# Out:
# [['Job', 'Function', ':', 'Admin', '&', 'Office'],
#  ['Job', 'Function', ':', 'Admin', '&', 'Office'],
#  ['Job', 'Function', ':', 'Management', '&', 'Business', 'Development'],
#  ['Job', 'Function', ':', 'Management', '&', 'Business', 'Development'],
#  ['Job', 'Function', ':', 'Management', '&', 'Business', 'Development'],
#  ['Job', 'Function', ':', 'Marketing', '&', 'Communications'],
#  ['Job', 'Function', ':', 'Estate', 'Agents', '&', 'Property', 'Management'],
#  ['Job', 'Function', ':', 'Marketing', '&', 'Communications']]
